# %%
import os, sys
import numpy as np
from matplotlib import pyplot as plt
sys.path.append("/Users/susung/Documents/02_Projects/porterble/")
from scripts.vehicle_interface.path_generator import *

# %%
cubic_func = cubic_parametrize(20, 10)

# %%
x = np.linspace(10, 20, 1000)
y = cubic_func(x)
plt.plot(x, y)
